# %%
import sys
import os
# Get the current working directory (where the notebook is running)
current_dir = os.getcwd()
# Go up one level to project root (adjust based on your structure)
project_root = os.path.dirname(current_dir)
sys.path.insert(0, project_root)

# %%
from pathlib import Path
from src.plots.parquet_plot import ParquetPlotting
pplt = ParquetPlotting()

result_dir = Path(r'C:\Users\ab177\Desktop\diffraction_results\1011long\analysis_logic_test')

# %%
pplt.add_parquet(result_dir / 'results\xps_179.56003.parquet')

pplt.density_mapping('center_x','center_y')
pplt.heatmap_plot(range(40,70,3))
