# %%
import sys
import os
# Get the current working directory (where the notebook is running)
current_dir = os.getcwd()
# Go up one level to project root (adjust based on your structure)
project_root = os.path.dirname(current_dir)
sys.path.insert(0, project_root)

# %%
from src.io.yaml_import import XPSIntensityMultiLoader
from src.plots.waterfall_plot import plot_waterfall_diffraction

# %%
loader = XPSIntensityMultiLoader(step=0.024)  # e.g. 0.5 eV per point, adjust as needed
    
# Load one or many files
loader.load_yaml(r"C:\Users\ab177\Desktop\diffraction_results\1013longccl4\analysis_logic_test\stats\xps_statistics_minor.yaml",198.08)

# Get the final data structure you wanted
data = loader.get_combined_data_baseline()
print(len(data))
# Out:
# Loaded 22 spectra from C:\Users\ab177\Desktop\diffraction_results\1013longccl4\analysis_logic_test\stats\xps_statistics_minor.yaml
# 22

# %%
from src.io.csv_to_list import csv_to_yaml_intensity

dataold = csv_to_yaml_intensity(r"C:\Users\ab177\Desktop\diffraction_results\1013long\analysis_logic_test\normalized",'')

# %%
plot_waterfall_diffraction(data= data,
                           scale= 1.5,
                           width_to_height_ratio= 0.5,
                           filename='')

# %%
plot_waterfall_diffraction(data= data,
                           scale= 1.5,
                           width_to_height_ratio= 0.5,
                           filename='')

# %%
plot_waterfall_diffraction(data= data,
                           scale= 1.5,
                           width_to_height_ratio= 0.5,
                           filename='')

# %%
plot_waterfall_diffraction(data= dataold,
                           scale= 1.5,
                           width_to_height_ratio= 0.5,
                           filename='')
